# %% [markdown]
# <a href="https://colab.research.google.com/github/Manithreddy23/MAIN-FLOW-SERVICES-AND-TECHNOLOGYS/blob/main/TASK_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('/content/diabetes_data.csv')

# %%
df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  SocioeconomicStatus  EducationLevel  \
# 0       6000   44       0          1                    2               1
# 1       6001   51       1          0                    1               2
# 2       6002   89       1          0                    1               3
# 3       6003   21       1          1                    1               2
# 4       6004   27       1          0                    1               3
#
#          BMI  Smoking  AlcoholConsumption  PhysicalActivity  ...  \
# 0  32.985284        1            4.499365          2.443385  ...
# 1  39.916764        0            1.578919          8.301264  ...
# 2  19.782251        0            1.177301          6.103395  ...
# 3  32.376881        1            1.714621          8.645465  ...
# 4  16.808600        0           15.462549          4.629383  ...
#
#    TinglingHandsFeet  QualityOfLifeScore  HeavyMetalsExposure  \
# 0                  1           73.765109                    0
# ...

# %%
df.tail()
# Out:
#       PatientID  Age  Gender  Ethnicity  SocioeconomicStatus  EducationLevel  \
# 1874       7874   37       0          0                    2               2
# 1875       7875   80       1          0                    2               2
# 1876       7876   38       1          0                    0               2
# 1877       7877   43       0          1                    2               0
# 1878       7878   85       1          0                    2               2
#
#             BMI  Smoking  AlcoholConsumption  PhysicalActivity  ...  \
# 1874  20.811137        0           10.946207          3.217636  ...
# 1875  27.694312        0           16.067905          7.107335  ...
# 1876  35.640824        0            4.865124          9.881212  ...
# 1877  32.423016        0            6.362936          4.750079  ...
# 1878  33.145119        0           13.854861          5.434137  ...
#
#       TinglingHandsFeet  QualityOfLifeScore  HeavyMetalsExposure  \
# ...

# %%
df.shape
# Out:
# (1879, 46)

# %%
df.size
# Out:
# 86434

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1879 entries, 0 to 1878
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   PatientID                      1879 non-null   int64
#  1   Age                            1879 non-null   int64
#  2   Gender                         1879 non-null   int64
#  3   Ethnicity                      1879 non-null   int64
#  4   SocioeconomicStatus            1879 non-null   int64
#  5   EducationLevel                 1879 non-null   int64
#  6   BMI                            1879 non-null   float64
#  7   Smoking                        1879 non-null   int64
#  8   AlcoholConsumption             1879 non-null   float64
#  9   PhysicalActivity               1879 non-null   float64
#  10  DietQuality                    1879 non-null   float64
#  11  SleepQuality                   1879 non-null   float64
# ...

# %%
df.describe()
# Out:
#          PatientID          Age       Gender    Ethnicity  \
# count  1879.000000  1879.000000  1879.000000  1879.000000
# mean   6939.000000    55.043108     0.487493     0.755721
# std     542.564896    20.515839     0.499977     1.047558
# min    6000.000000    20.000000     0.000000     0.000000
# 25%    6469.500000    38.000000     0.000000     0.000000
# 50%    6939.000000    55.000000     0.000000     0.000000
# 75%    7408.500000    73.000000     1.000000     1.000000
# max    7878.000000    90.000000     1.000000     3.000000
#
#        SocioeconomicStatus  EducationLevel          BMI      Smoking  \
# count          1879.000000     1879.000000  1879.000000  1879.000000
# mean              0.992017        1.699308    27.687601     0.281533
# std               0.764940        0.885665     7.190975     0.449866
# min               0.000000        0.000000    15.025898     0.000000
# 25%               0.000000        1.000000    21.469981     0.000000
# ...

# %%
df=df.drop_duplicates()
df.shape
# Out:
# (1879, 46)

# %%
df.isnull().sum()
# Out:
# PatientID                        0
# Age                              0
# Gender                           0
# Ethnicity                        0
# SocioeconomicStatus              0
# EducationLevel                   0
# BMI                              0
# Smoking                          0
# AlcoholConsumption               0
# PhysicalActivity                 0
# DietQuality                      0
# SleepQuality                     0
# FamilyHistoryDiabetes            0
# GestationalDiabetes              0
# PolycysticOvarySyndrome          0
# PreviousPreDiabetes              0
# Hypertension                     0
# SystolicBP                       0
# DiastolicBP                      0
# FastingBloodSugar                0
# HbA1c                            0
# SerumCreatinine                  0
# BUNLevels                        0
# CholesterolTotal                 0
# CholesterolLDL                   0
# CholesterolHDL                   0
# CholesterolTriglycerides         0
# ...

# %%
df.columns
# Out:
# Index(['PatientID', 'Age', 'Gender', 'Ethnicity', 'SocioeconomicStatus',
#        'EducationLevel', 'BMI', 'Smoking', 'AlcoholConsumption',
#        'PhysicalActivity', 'DietQuality', 'SleepQuality',
#        'FamilyHistoryDiabetes', 'GestationalDiabetes',
#        'PolycysticOvarySyndrome', 'PreviousPreDiabetes', 'Hypertension',
#        'SystolicBP', 'DiastolicBP', 'FastingBloodSugar', 'HbA1c',
#        'SerumCreatinine', 'BUNLevels', 'CholesterolTotal', 'CholesterolLDL',
#        'CholesterolHDL', 'CholesterolTriglycerides',
#        'AntihypertensiveMedications', 'Statins', 'AntidiabeticMedications',
#        'FrequentUrination', 'ExcessiveThirst', 'UnexplainedWeightLoss',
#        'FatigueLevels', 'BlurredVision', 'SlowHealingSores',
#        'TinglingHandsFeet', 'QualityOfLifeScore', 'HeavyMetalsExposure',
#        'OccupationalExposureChemicals', 'WaterQuality',
#        'MedicalCheckupsFrequency', 'MedicationAdherence', 'HealthLiteracy',
# ...

# %%
df.drop(['PatientID','DoctorInCharge'],axis=1 ,inplace=True)
df.columns
# Out:
# Index(['Age', 'Gender', 'Ethnicity', 'SocioeconomicStatus', 'EducationLevel',
#        'BMI', 'Smoking', 'AlcoholConsumption', 'PhysicalActivity',
#        'DietQuality', 'SleepQuality', 'FamilyHistoryDiabetes',
#        'GestationalDiabetes', 'PolycysticOvarySyndrome', 'PreviousPreDiabetes',
#        'Hypertension', 'SystolicBP', 'DiastolicBP', 'FastingBloodSugar',
#        'HbA1c', 'SerumCreatinine', 'BUNLevels', 'CholesterolTotal',
#        'CholesterolLDL', 'CholesterolHDL', 'CholesterolTriglycerides',
#        'AntihypertensiveMedications', 'Statins', 'AntidiabeticMedications',
#        'FrequentUrination', 'ExcessiveThirst', 'UnexplainedWeightLoss',
#        'FatigueLevels', 'BlurredVision', 'SlowHealingSores',
#        'TinglingHandsFeet', 'QualityOfLifeScore', 'HeavyMetalsExposure',
#        'OccupationalExposureChemicals', 'WaterQuality',
#        'MedicalCheckupsFrequency', 'MedicationAdherence', 'HealthLiteracy',
#        'Diagnosis'],
#       dtype='object')

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR  =Q3-Q1
print(IQR)
# Out:
# Age                               35.000000
# Gender                             1.000000
# Ethnicity                          1.000000
# SocioeconomicStatus                2.000000
# EducationLevel                     1.000000
# BMI                               12.386479
# Smoking                            1.000000
# AlcoholConsumption                10.495634
# PhysicalActivity                   4.920380
# DietQuality                        4.879256
# SleepQuality                       3.042025
# FamilyHistoryDiabetes              0.000000
# GestationalDiabetes                0.000000
# PolycysticOvarySyndrome            0.000000
# PreviousPreDiabetes                0.000000
# Hypertension                       0.000000
# SystolicBP                        44.000000
# DiastolicBP                       30.000000
# FastingBloodSugar                 65.020892
# HbA1c                              2.979356
# SerumCreatinine                    2.243660
# ...

# %%
df=df[~((df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))).any(axis=1)]
df
# Out:
#       Age  Gender  Ethnicity  SocioeconomicStatus  EducationLevel        BMI  \
# 4      27       1          0                    1               3  16.808600
# 5      65       0          0                    0               0  15.820815
# 21     88       1          0                    0               1  26.684686
# 34     24       1          0                    1               2  33.519385
# 48     58       0          1                    1               2  18.033401
# ...   ...     ...        ...                  ...             ...        ...
# 1839   89       1          0                    0               1  39.512150
# 1846   36       0          1                    0               2  22.723879
# 1850   26       0          0                    1               0  25.025957
# 1858   89       0          0                    2               2  26.198771
# 1876   38       1          0                    0               2  35.640824
#
# ...

# %%
df.describe()
# Out:
#               Age      Gender   Ethnicity  SocioeconomicStatus  \
# count  228.000000  228.000000  228.000000           228.000000
# mean    58.565789    0.482456    0.486842             0.991228
# std     21.660375    0.500792    0.717805             0.807406
# min     20.000000    0.000000    0.000000             0.000000
# 25%     41.000000    0.000000    0.000000             0.000000
# 50%     59.500000    0.000000    0.000000             1.000000
# 75%     78.000000    1.000000    1.000000             2.000000
# max     90.000000    1.000000    2.000000             2.000000
#
#        EducationLevel         BMI     Smoking  AlcoholConsumption  \
# count      228.000000  228.000000  228.000000          228.000000
# mean         1.671053   28.163020    0.293860           10.315602
# std          0.824538    7.166572    0.456531            5.983761
# min          0.000000   15.140166    0.000000            0.082784
# ...

# %%
df.hist(bins=60 , grid=False , figsize=(20,15));

# %%
plt.plot(df['Age'],df['Diagnosis'])
plt.title("Line Chart")
plt.xlabel("AGE")
plt.ylabel("DIAGNOSIS")
plt.show()

# %%
df.EducationLevel.value_counts()
# Out:
# EducationLevel
# 2    97
# 1    79
# 3    36
# 0    16
# Name: count, dtype: int64

# %%
df.EducationLevel.value_counts().plot(kind='bar',color=['salmon','lightskyblue','springgreen','khaki'])
plt.title("Educational Level vs count");

# %%
questions = ["1.How many people have diabetes and how many people don't have diabetes ?",
             "2.How many Male and Female have Diabetes ?",
             "3.How many smoking people have diabetes ? ",
             "4.How many Educational Level people have Diabetes ?",
             "5.How many people get quality water and sill have Diabetes for Gender ?"]
questions
# Out:
# ["1.How many people have diabetes and how many people don't have diabetes ?",
#  '2.How many Male and Female have Diabetes ?',
#  '3.How many smoking people have diabetes ? ',
#  '4.How many Educational Level people have Diabetes ?',
#  '5.How many people get quality water and sill have Diabetes for Gender ?']

# %%
# Question one answer
# How  many people have diabetes and how many people don't have diabetes ?

df.Diagnosis.value_counts()
# Out:
# Diagnosis
# 0    165
# 1     63
# Name: count, dtype: int64

# %%
# Bar Chart

df.Diagnosis.value_counts().plot(kind='bar',color=['orchid','salmon'])
plt.title('Diabetes value counts')
plt.xlabel('1=Dibetes,0=Not Diabetes')
plt.ylabel('Value Counts');

# %%
# Question Two
# How many Male and Female have Diabetes ?
# 0 - Male
# 1 - Female

df.Gender.value_counts()
# Out:
# Gender
# 0    118
# 1    110
# Name: count, dtype: int64

# %%
df.Gender.value_counts().plot(kind='pie',figsize=(8,6))
plt.title('Male Female Ratio')
plt.legend(['Male','Female']);

# %%
pd.crosstab(df.Diagnosis , df.Gender)
# Out:
# Gender      0   1
# Diagnosis
# 0          85  80
# 1          33  30

# %%
pd.crosstab(df.Diagnosis,df.Gender).plot(kind='bar',color=['lightskyblue','plum'])
plt.title('Diabetes According to Gender')
plt.xlabel("0=Male,1=Female");

# %%
# Question three
# How many Smoking people have Diabetes ?

pd.crosstab(df.Diagnosis , df.Smoking)
# Out:
# Smoking      0   1
# Diagnosis
# 0          124  41
# 1           37  26

# %%
pd.crosstab(df.Diagnosis , df.Smoking).plot(kind='bar',color=['coral','khaki'])
plt.title('How many Smoking people has diabetes')
plt.xlabel('0=Non Smoking ,1=Smoking');

# %%
# Question four
# How many Educational Level people have Diabetes ?

pd.crosstab(df.Diagnosis , df.EducationLevel)
# Out:
# EducationLevel   0   1   2   3
# Diagnosis
# 0               10  57  71  27
# 1                6  22  26   9

# %%
pd.crosstab(df.Diagnosis , df.EducationLevel).plot(kind='bar',color=['coral','lightskyblue','plum','khaki'])
plt.title('Education For Diabetes People')
plt.xlabel('Education Level');

# %%
# Question Five
# How many Daibetes people get drinkable or not drinkable water ?
# 0 = Drinkable , 1=NotDrinkable

pd.crosstab(df.Gender,df.WaterQuality)
# Out:
# WaterQuality    0
# Gender
# 0             118
# 1             110

# %%
pd.crosstab(df.Gender,df.WaterQuality).plot(kind='bar',color=['lightskyblue','plum'])
plt.title('Water Quality for Diabetes Peolple')
plt.xlabel("0=Drinkable,1=Not Drinkable")  ;

# %%
pd.crosstab(df.Diagnosis,df.WaterQuality)
# Out:
# WaterQuality    0
# Diagnosis
# 0             165
# 1              63

# %%
pd.crosstab(df.Diagnosis,df.WaterQuality).plot(kind='bar',color=['lightskyblue','plum'])
plt.title('Water Quality for Diabetes Peolple')
plt.xlabel("0=Male,1=Female")  ;
